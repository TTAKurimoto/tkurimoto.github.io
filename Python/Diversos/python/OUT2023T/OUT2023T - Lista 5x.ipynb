# %% [markdown]
# 1-Escreva um programa que pergunte a velocidade do carro de um usuário.
#
# Caso ultrapasse 80km/h, exiba uma mensagem dizendo que o usuário foi multado. Nesse caso, exiba o valor da
# multa, cobrando R$ 55 por cada km acima de 80 km/h, caso contrário, exiba uma mensagem que a velocidade está ok.

# %% [markdown]
# 2-Escreva um programa que pergunte o salário do funcionário e calcule o valor do aumento.
#
# Para salários superiores a R$ 2.250,00, calcule um aumento de 10%. Para os inferiores ou iguais, de
# 15%.
#
# Imprimir o valor do aumento, a porcentagem e o valor do salário com o aumento.

# %% [markdown]
# 3-Escreva um programa que pergunte a distância que um passageiro deseja percorrer em km.
#
# Calcule o preço da passagem, cobrando R$ 0,50 por km para viagens de até de 200 km, e R$
# 0,30 para viagens mais longas.
#
# Imprimir o valor da passagem.

# %% [markdown]
# 4-Escreva um programa para calcular o valor da parcela de um empréstimo e a aprovaçãõ mediante análise.
#
# O programa deve perguntar o valor do empréstimo, a taxa de juros mensal, quantidade de meses a pagar e por fim o salário.
#
# a. Para calcular o valor da parcela, primeiro encontre o **coeficiente de financiamento** (CF) usando a fórmula:
#
# $CF = \frac{i}{1 - \left(1 + i\right)^{n}}$
#
# Onde:
# - *CF* é o coeficiente de financiamento.
# - *i* é a taxa de juros (se a tx for 3% am a taxa deve ser digitada 0.03)
# - *n* é o número de parcelas.
#
# b. Para calcular o valor da prestação multiplique o coeficiente de financiamento pelo valor do empréstimo.
#
# c. Analise se o cliente poderá obter o empréstimo de acordo com o seguinte critério:
#
# - Se o valor da parcela for maior do que 30% do valor do salário: Imprimir o resultado da analise: Infelizmente você não pode obter o empréstimo, *Valor da parcela:* (exibir o valor da parcela) acima do limite.
#
# - Caso contrário: Imprimir o resultado da analise: Empréstimo OK! *Valor da parcela:* (exibir o valor da parcela)

# %% [markdown]
# 5-Era uma vez uma terra habitada por pessoas felizes e prósperas. As pessoas pagavam impostos, é claro - a felicidade tinha limites. O imposto mais importante, chamado de imposto de renda pessoal (PIT) tinha que ser pago uma vez por ano e é avaliado usando a seguinte regra:
#
# - Se a renda do cidadão for inferior a R$85.528, o imposto é igual a 18% da renda, menos R$556 (dedução de imposto).
# - Se a receita for superior a esse valor, o imposto será igual a 26% da renda, mais R$14.839 (acréscimo de imposto).
#
#
# Sua tarefa é escrever uma calculadora de impostos, ele deve imprimir o imposto calculado, arredondado para inteiro.
# Obs.: Há uma função chamada round() que fará o arredondamento para você
#
# Nota: esse país feliz nunca devolve dinheiro de impostos para seus cidadãos...

# %% [markdown]
# 6- Você está criando um programa que calcula o imposto de renda com base no salário anual de uma pessoa. O programa deve aplicar diferentes alíquotas de imposto com base no salário da seguinte forma:
#
# - Até R$ 15.000: Isento de imposto.
# - De R$ 15.001 a R$ 30.000: 10% de imposto.
# - De R$ 30.001 a R$ 45.000: 15% de imposto.
# - Acima de R$ 45.000: 20% de imposto.
#
# Escreva um programa Python que solicita ao usuário seu salário anual e, em seguida, calcula e exibe o valor do imposto devido.
#
# Neste programa, a instrução `if` deve ser usada para determinar a alíquota de imposto com base no salário anual fornecido pelo usuário. As instruções `elif` devem verificar os diferentes intervalos de salário e a instrução `else` será usada para os salários acima de R$ 45.000.

# %% [markdown]
# 7-Você está criando um programa que ajuda os motoristas a calcular sua economia de combustível em uma viagem. O programa deve solicitar ao usuário os seguintes detalhes:
#
# - O número de quilômetros percorridos na viagem.
# - A quantidade de combustível consumida na viagem (em litros).
#
# Em seguida, o programa deve calcular a economia de combustível em quilômetros por litro (Km/L) e em milhas por galão (MPG) e exibir os resultados.
#
# A fórmula para calcular a economia de combustível em Km/L é:
#
# **economia Km/L = Número de Quilometros/Quantidade de Combustível Consumida**
#
# Em seguida, o programa deve classificá-la em uma das seguintes categorias:
#
# - Excelente (acima de 15 Km/L)
# - Bom (entre 10 e 15 Km/L)
# - Regular (entre 5 e 10 Km/L)
# - Ruim (menos de 5 Km/L)

# %% [markdown]
# 8-Você está criando um programa que fornece uma classificação do clima com base na temperatura atual em graus Celsius. O programa deve solicitar ao usuário que insira a temperatura e, em seguida, classificar o clima de acordo com as seguintes categorias:
#
# - Temperatura abaixo de 0°C: Clima Muito Frio
# - Temperatura de 0°C a 10°C: Clima Frio
# - Temperatura de 11°C a 20°C: Clima Ameno
# - Temperatura de 21°C a 30°C: Clima Quente
# - Temperatura acima de 30°C: Clima Muito Quente
#
# Escreva um programa Python que recebe a temperatura do usuário e, em seguida, exibe a classificação do clima.

# %% [markdown]
# 9-Você está criando um programa que ajuda as pessoas a calcular seu Índice de Massa Corporal (IMC) com base em seu peso e altura. O IMC é uma medida comum de avaliação do peso corporal e saúde.
#
# O programa deve solicitar ao usuário que insira seu peso em quilogramas e sua altura em metros,
#
# imc = (peso / altura²)
#
# Calcular o IMC e classificar a faixa do IMC de acordo com as seguintes categorias:
#
# - Abaixo de 18.5: Abaixo do peso
# - 18.5 a 24.9: Peso normal
# - 25 a 29.9: Sobrepeso
# - 30 a 34.9: Obesidade grau 1
# - 35 a 39.9: Obesidade grau 2
# - 40 ou mais: Obesidade grau 3 (mórbida)
#
# Escreva um programa Python que recebe o peso e a altura do usuário, calcula o IMC e, em seguida, exibe a classificação do IMC.

# %% [markdown]
# 10- Como você certamente sabe, devido a algumas razões astronômicas, os anos podem ser bissextos ou comuns. Os primeiros têm 366 dias, enquanto os segundos têm 365 dias.
#
# Desde a introdução do calendário gregoriano (em 1582), a regra a seguir é usada para determinar o tipo de ano:
#
# - se o número do ano não é divisível por quatro, é um ano comum;
# - caso contrário, se o número do ano não for divisível por 100, será um ano bissexto;
# - caso contrário, se o número do ano não for divisível por 400, é um ano comum ;
# - caso contrário, é um ano bissexto .
#
# O código deve gerar as mensagens possíveis (ano comum ou ano bissexto), dependendo do ano informado.
#
# Dica1:
#
# use os operadores % e !=
#
# Dica2:
#
#  ```
#  if ano % 4 != 0:
#       print("Ano comum")
# ```
